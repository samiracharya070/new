# %%
import pandas as pd
import numpy as np

# %%
data = {'name': ["Aarav Sharma","Priya Koirala","Rohan Thapa","Sita Gurung","Manish Shrestha","Sita Gurung","Aarav Sharma"],'total':[40,45,50,60,70,60,60]}

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#               name  total
# 0     Aarav Sharma     40
# 1    Priya Koirala     45
# 2      Rohan Thapa     50
# 3      Sita Gurung     60
# 4  Manish Shrestha     70
# 5      Sita Gurung     60
# 6     Aarav Sharma     60

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# dtype: bool

# %%
df.duplicated().value_counts()
# Out:
# False    6
# True     1
# Name: count, dtype: int64

# %%
df.drop_duplicates()    
# df.drop_duplicates(keep= 'first')   remove all duplicate data except first
# Out:
#               name  total
# 0     Aarav Sharma     40
# 1    Priya Koirala     45
# 2      Rohan Thapa     50
# 3      Sita Gurung     60
# 4  Manish Shrestha     70
# 6     Aarav Sharma     60

# %%
df
# Out:
#               name  total
# 0     Aarav Sharma     40
# 1    Priya Koirala     45
# 2      Rohan Thapa     50
# 3      Sita Gurung     60
# 4  Manish Shrestha     70
# 5      Sita Gurung     60
# 6     Aarav Sharma     60

# %%
df.shape
# Out:
# (7, 2)

# %%
dataset = pd.read_csv('student_per.csv')
dataset.head()
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A

# %%
dataset.duplicated().value_counts()
# Out:
# False    998
# Name: count, dtype: int64

# %%
dataset.drop_duplicates()
# Out:
#      student_id  weekly_self_study_hours  attendance_percentage  \
# 0             1                     18.5                   95.6
# 1             2                     14.0                   80.0
# 2             3                     19.5                   86.3
# 3             4                     25.7                   70.2
# 4             5                     13.4                   81.9
# ..          ...                      ...                    ...
# 993         994                     10.2                   77.6
# 994         995                      8.0                   94.0
# 995         996                     13.0                   72.5
# 996         997                     27.6                   92.9
# 997         998                     19.5                   70.2
#
#      class_participation  total_score grade
# 0                    3.8         97.9     A
# 1                    2.5         83.9     B
# 2                    5.3        100.0     A
# ...

# %%
dataset.count()
# Out:
# student_id                 998
# weekly_self_study_hours    998
# attendance_percentage      998
# class_participation        998
# total_score                998
# grade                      998
# dtype: int64
