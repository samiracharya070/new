# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("student.csv")
dataset.head(),dataset.tail(3)
# Out:
# (   rollno              name   sci   eng  math   nep total
#  0       1   Anisha Bhandari  78.0  76.0   NaN  72.0   279
#  1       2    Gita Bhattarai  91.0   NaN  62.0   NaN   NaN
#  2       3               NaN   NaN  46.0  99.0   NaN   307
#  3       4  Pramila Maharjan  54.0  60.0  96.0  62.0   272
#  4       5  Krishna Shrestha  82.0  48.0  79.0  63.0   272,
#      rollno           name   sci   eng  math   nep total
#  46      47  Mina Bhandari  90.0  63.0  88.0  71.0   312
#  47      48  Sanjana Limbu  66.0   NaN  53.0  70.0   NaN
#  48      49      Binod Par  79.0   NaN   NaN   NaN   NaN)

# %%
dataset.shape
# Out:
# (49, 7)

# %%
print(f"number of row :{dataset.shape[0]}\nnumber of column :{dataset.shape[1]}")
# Out:
# number of row :49
# number of column :7

# %%
dataset.isna().head(10)
# Out:
#    rollno   name    sci    eng   math    nep  total
# 0   False  False  False  False   True  False  False
# 1   False  False  False   True  False   True   True
# 2   False   True   True  False  False   True  False
# 3   False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False
# 5   False  False  False  False  False   True   True
# 6   False  False  False  False   True  False  False
# 7   False  False  False  False   True  False  False
# 8   False   True  False  False  False   True  False
# 9   False  False  False  False  False  False  False

# %%
dataset.isna().sum()
# Out:
# rollno     0
# name       4
# sci        3
# eng        8
# math      12
# nep        8
# total      4
# dtype: int64

# %%
dataset.isna().sum().sum()
# Out:
# np.int64(39)

# %%
(dataset.isna().sum()/dataset.shape[0])*100
# Out:
# rollno     0.000000
# name       8.163265
# sci        6.122449
# eng       16.326531
# math      24.489796
# nep       16.326531
# total      8.163265
# dtype: float64

# %%
(dataset.isna().sum().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# np.float64(11.370262390670554)

# %%
dataset.notna().sum(),dataset.notna().sum().sum()
# Out:
# (rollno    49
#  name      45
#  sci       46
#  eng       41
#  math      37
#  nep       41
#  total     45
#  dtype: int64,
#  np.int64(304))

# %%
sns.heatmap(dataset.isna())
plt.show()

# %% [markdown]
# fill the missing value different types

# %%
# dataset.fillna(0,inplace= True)  # fill the missing value with zero (0)
# dataset.fillna(75,inplace=True)   # fill the missing value with 75
# dataset.fillna(method ="ffill",inplace=True)   # Fill missing values with the previous value
# dataset.fillna(method = "bfill",inplace=True)   # Fill missing values with the next value
dataset.head()
# Out:
#    rollno              name   sci   eng  math   nep total
# 0       1   Anisha Bhandari  78.0  76.0   NaN  72.0   279
# 1       2    Gita Bhattarai  91.0   NaN  62.0   NaN   NaN
# 2       3               NaN   NaN  46.0  99.0   NaN   307
# 3       4  Pramila Maharjan  54.0  60.0  96.0  62.0   272
# 4       5  Krishna Shrestha  82.0  48.0  79.0  63.0   272

# %%
# dataset['sci'].mean()
# dataset['nep'].fillna(dataset['nep'].mean(),inplace=True)
# dataset.head(7)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_16236\1108164406.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset['nep'].fillna(dataset['nep'].mean(),inplace=True)
#    rollno              name   sci   eng  math       nep total
# 0       1   Anisha Bhandari  78.0  76.0   NaN  72.00000   279
# 1       2    Gita Bhattarai  91.0   NaN  62.0  65.04878   NaN
# 2       3               NaN   NaN  46.0  99.0  65.04878   307
# 3       4  Pramila Maharjan  54.0  60.0  96.0  62.00000   272
# ...

# %%
dataset['name'].mode()[0]
dataset['name'].fillna(dataset['name'].mode()[0] ,inplace =True)
dataset.head(5)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rollno  49 non-null     int64
#  1   name    45 non-null     object
#  2   sci     46 non-null     float64
#  3   eng     41 non-null     float64
#  4   math    37 non-null     float64
#  5   nep     49 non-null     float64
#  6   total   45 non-null     object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 2.8+ KB

# %%
dataset.select_dtypes(include='float64').columns
# Out:
# Index(['sci', 'eng', 'math', 'nep'], dtype='object')

# %%
for i in dataset.select_dtypes(include='float64').columns:
    dataset[i].fillna(dataset[i].mean(),inplace=True)
    
dataset.head(5)
