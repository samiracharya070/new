# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('student_per.csv')
dataset.head(6)
# Out:
#    student_id  weekly_self_study_hours  attendance_percentage  \
# 0           1                     18.5                   95.6
# 1           2                     14.0                   80.0
# 2           3                     19.5                   86.3
# 3           4                     25.7                   70.2
# 4           5                     13.4                   81.9
# 5           6                     13.4                   65.1
#
#    class_participation  total_score grade
# 0                  3.8         97.9     A
# 1                  2.5         83.9     B
# 2                  5.3        100.0     A
# 3                  7.0        100.0     A
# 4                  6.9         92.0     A
# 5                  5.0         97.5     A

# %%
dataset.isna().sum()
# Out:
# student_id                 0
# weekly_self_study_hours    0
# attendance_percentage      0
# class_participation        0
# total_score                0
# grade                      0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 998 entries, 0 to 997
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               998 non-null    int64
#  1   weekly_self_study_hours  998 non-null    float64
#  2   attendance_percentage    998 non-null    float64
#  3   class_participation      998 non-null    float64
#  4   total_score              998 non-null    float64
#  5   grade                    998 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 46.9+ KB

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(y='weekly_self_study_hours',x='total_score',data= dataset)
plt.show()

# %%
sns.pairplot(data=dataset)
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=dataset[['weekly_self_study_hours']]
x.ndim
# Out:
# 2

# %%
y= dataset['total_score']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test) *100
# Out:
# 62.536821314028

# %%
lr.predict([[13.4]])
# Out:
# c:\Users\Acer\Desktop\Samir\.venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([81.76201465])

# %%
y_pre= lr.predict(x)

# %%
plt.figure(figsize=(7,4))
sns.scatterplot(y='weekly_self_study_hours',x='total_score',data= dataset)
plt.plot(dataset['weekly_self_study_hours'],y_pre ,c='red')
plt.show()

# %%
dataset_2 = pd.read_csv('student_2.csv')
dataset_2.head(6)
# Out:
#    rollno             name  sci  eng  math  nep  soc  total
# 0       1     Aarav Sharma   85   79    92   88   90    436
# 1       2   Prisha Koirala   78   82    80   85   79    404
# 2       3      Rohan Thapa   91   87    95   89   92    454
# 3       4      Sita Gurung   69   73    70   75   72    359
# 4       5  Manish Shrestha   88   90    85   91   87    441
# 5       6  Anisha Bhandari   75   80    77   79   81    392

# %%
dataset_2.isna().sum()
# Out:
# rollno    0
# name      0
# sci       0
# eng       0
# math      0
# nep       0
# soc       0
# total     0
# dtype: int64

# %%
dataset_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   rollno  20 non-null     int64
#  1   name    20 non-null     object
#  2   sci     20 non-null     int64
#  3   eng     20 non-null     int64
#  4   math    20 non-null     int64
#  5   nep     20 non-null     int64
#  6   soc     20 non-null     int64
#  7   total   20 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 1.4+ KB

# %%
# dataset_3=dataset_2.dropna()
# dataset_3.head(6)

# %%
dataset_2.shape
# Out:
# (20, 8)

# %%
# dataset_3.shape

# %%
# float_cols = dataset_2.select_dtypes(include='float64').columns
# float_cols

# %%
# for i in dataset_2.select_dtypes(include='float64').columns:
#     dataset_2[i].fillna(dataset_2[i].mean(),inplace=True)
    
# dataset_2.head(5)

# %%
# dataset_4 = dataset_2.dropna()
# dataset_4.shape

# %%
# dataset_4.isna().sum()

# %%
sns.pairplot(data = dataset_2)
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.scatterplot(x='nep',y='total',data=dataset_2)
plt.subplot(1,2,2)
sns.scatterplot(x='soc',y='total',data=dataset_2)
plt.show()

# %%
new_data = dataset_2.drop(columns='name')

# %%
sns.heatmap(data=new_data.corr(),annot=True)
plt.show()

# %% [markdown]
# does not found highly corealtion data

# %%
dataset_2.columns
# Out:
# Index(['rollno', 'name', 'sci', 'eng', 'math', 'nep', 'soc', 'total'], dtype='object')

# %%
x= dataset_2[['nep','soc']]
y= dataset_2['total']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train2,x_test2,y_train2,y_test2 = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
mlr = LinearRegression()
mlr.fit(x_train2,y_train2)
# Out:
# LinearRegression()

# %%
mlr.score(x_test2,y_test2) *100
# Out:
# 94.67928690648344

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.scatterplot(x='nep',y='total',data=dataset_2)
sns.lineplot(x='nep',y= mlr.predict(x),data=dataset_2,color= 'red')
plt.subplot(1,2,2)
sns.scatterplot(x='soc',y='total',data=dataset_2)
sns.lineplot(x='nep',y= mlr.predict(x),data=dataset_2,color= 'red')
plt.show()
